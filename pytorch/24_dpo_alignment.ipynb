# %% [markdown]
# # Direct Preference Optimization (DPO) for LLM Alignment (From Scratch)
# In this notebook, we explore the implementation and application of Direct Preference Optimization (DPO) in reinforcement learning, a technique highlighted in the paper "Direct Preference Optimization (DPO) for RLHF". DPO is a method designed to directly optimize for human preferences, leveraging feedback to guide the learning process toward outcomes that align with human values and judgments.
#
# Traditional reinforcement learning (RL) often focuses on maximizing rewards that are predefined and may not always reflect the nuances of human preferences. In contrast, DPO allows for a more nuanced approach by incorporating human feedback directly into the optimization process, bridging the gap between reward maximization and preference satisfaction.
#
# The objective of this notebook is to:
# Implement the DPO loss function as described in the paper, specifically referencing Equation 7.
# Understand how DPO integrates human feedback into the RL framework.
# Evaluate the performance of DPO in a simple RL environment.
#
# ![image.png](attachment:image.png)
#
# # References:
# * https://github.com/rasbt/LLMs-from-scratch/blob/main/ch07/04_preference-tuning-with-dpo/dpo-from-scratch.ipynb
#
# * https://arxiv.org/pdf/2305.18290.pdf

# %% [markdown]
# &nbsp;
# # 1) A brief introduction to DPO

# %% [markdown]
# # Process Data

# %% [markdown]
# - DPO, proposed in the paper [Direct Preference Optimization: Your Language Model is Secretly a Reward Model](https://arxiv.org/abs/2305.18290), is an alternative to reinforcement learning from human feedback (RLHF) used in finetuning large language models (LLMs)
# - DPO can be used to finetune (or align) the model to generate responses that better align with user expectations and instructions
#
# <img src="https://sebastianraschka.com/images/LLMs-from-scratch-images/dpo/1.webp" width=500px>
#
# - In instruction finetuning, we train the LLM to generate correct answers given a prompt
# - However, in practice, there are multiple ways to give a correct answer, and correct answers can differ in style; for example, consider a technical and a more user-friendly response when asking an LLM to give recommendations when buying a laptop, as shown in the figure below
#
# <img src="https://sebastianraschka.com/images/LLMs-from-scratch-images/dpo/2.webp" width=700px>
#
# - RLHF and DPO are methods that can be used to teach the LLM to prefer one answer style over the other, that is, aligning better with user preferences
# - The RLHF process, which requires training a separate reward model, is outlined below
#
# <img src="https://sebastianraschka.com/images/LLMs-from-scratch-images/dpo/4.webp" width=600px>

# %% [markdown]
# - Compared to RLHF, DPO aims to simplify the process by optimizing models directly for user preferences without the need for complex reward modeling and policy optimization
# - In other words, DPO focuses on directly optimizing the model's output to align with human preferences or specific objectives
# - Shown below is the main idea as an overview of how DPO works
#
# <img src="https://sebastianraschka.com/images/LLMs-from-scratch-images/dpo/5.webp?123" width=600px>

# %%
import time
import json
import pprint
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import tiktoken
import matplotlib.pyplot as plt

from typing import List, Tuple, Dict, Any, Union, Optional
from pathlib import Path
from matplotlib.ticker import MaxNLocator
from functools import partial
from torch.optim import AdamW
from torch.utils.data import Dataset, DataLoader
from tiktoken import Encoding
from transformers import GPT2LMHeadModel

# %% [markdown]
# &nbsp;
# # 2) Preparing a preference dataset for DPO

# %% [markdown]
# ### 2.1 Load a preference dataset
#
# Source:
#
# * https://github.com/rasbt/LLMs-from-scratch/blob/f1c3d451fe4d9a0856fef61d4c6cb5495825c23f/ch07/04_preference-tuning-with-dpo/instruction-data-with-preference.json
#
# * The dataset was generated via the [create-preference-data-ollama.ipynb](create-preference-data-ollama.ipynb) notebook
#
# - The dataset is a json file with 1100 entries:

# %%
preference_file_path = "datasets/dpo_dataset/instruction-data-with-preference.json"

# %%
with open(preference_file_path, "r", encoding="utf-8") as file:
    data = json.load(file)

print("Number of entries:", len(data))
# Out:
# Number of entries: 1100

# %% [markdown]
# Let's take a look at two example entries:
#
# The dataset consists of 5 keys:
#
# * The `'instruction'` and `'input'` that are used as LLM inputs
# * The `'output'` contains the response the model was trained on via the instruction finetuning step in chapter 7
# * The `'chosen'` and `'rejected'` entries are the entries we use for DPO; here `'chosen'` is the preferred response, and `'rejected'` is the dispreferred response
#
# The goal is to get the model to follow the style of the chosen over the rejected responses

# %%
pprint.pp(data[50])
# Out:
# {'instruction': 'Identify the correct spelling of the following word.',
#  'input': 'Ocassion',
#  'output': "The correct spelling is 'Occasion.'",
#  'rejected': "The correct spelling is obviously 'Occasion.'",
#  'chosen': "The correct spelling is 'Occasion.'"}

# %%
pprint.pp(data[999])
# Out:
# {'instruction': "What is an antonym of 'complicated'?",
#  'input': '',
#  'output': "An antonym of 'complicated' is 'simple'.",
#  'chosen': "A suitable antonym for 'complicated' would be 'simple'.",
#  'rejected': "An antonym of 'complicated' is 'simple'."}

# %% [markdown]
# ### 2.3 Process the chosen and rejected entries in the dataset using the Alpaca prompt style.
#
# References:
#
# * [Alpaca Input Template Discussion](https://huggingface.co/cognitivecomputations/dolphin-2.0-mistral-7b/discussions/3)
#
# * [Reference Code](https://github.com/rasbt/LLMs-from-scratch/blob/main/ch07/01_main-chapter-code/ch07.ipynb)

# %%
def format_input(entry: str) -> str:
    """Takes an entry and returns a formatted string using Alpaca template."""

    instruction_text = (
        f"Below is an instruction that describes a task. "
        f"Write a response that appropriately completes the request."
        f"\n\n### Instruction:\n{entry['instruction']}"
    )

    input_text = f"\n\n### Input:\n{entry['input']}" if entry["input"] else ""

    return instruction_text + input_text

# %%
# Format input for the example entry
model_input = format_input(data[999])
print(model_input)
# Out:
# Below is an instruction that describes a task. Write a response that appropriately completes the request.
#
# ### Instruction:
# What is an antonym of 'complicated'?

# %%
# Format user response for the example entry
desired_response = f"### Response:\n{data[999]['chosen']}"
print(desired_response)
# Out:
# ### Response:
# A suitable antonym for 'complicated' would be 'simple'.

# %%
# Format model response for the example entry
possible_response = f"### Response:\n{data[999]['rejected']}"
print(possible_response)
# Out:
# ### Response:
# An antonym of 'complicated' is 'simple'.

# %% [markdown]
# ### 2.3 Creating training, validation, and test splits
#
# Divide the dataset into training, validation, and test splits
# * Training: 85%
# * Validation: 5%
# * Test: 10%

# %%
train_portion = int(len(data) * 0.85)  # 85% for training
test_portion = int(len(data) * 0.1)  # 10% for testing
val_portion = len(data) - train_portion - test_portion  # Remaining 5% for validation

train_data = data[:train_portion]
test_data = data[train_portion : train_portion + test_portion]
val_data = data[train_portion + test_portion :]

# %%
print("Training set length:", len(train_data))
print("Validation set length:", len(val_data))
print("Test set length:", len(test_data))
# Out:
# Training set length: 935
# Validation set length: 55
# Test set length: 110

# %% [markdown]
# ### 2.4 Developing a `PreferenceDataset` class and batch processing function

# %% [markdown]
# - In this section, we rewrite the `InstructionDataset` class from chapter 7 ([../01_main-chapter-code/ch07.ipynb](../01_main-chapter-code/ch07.ipynb)) for DPO
# - This means that instead of focusing on single output sequences (responses), we modify the dataset class to return pairs of responses where one is preferred ("chosen") over the other ("rejected")
# - Overall, the `PreferenceDataset` is almost identical to the `InstructionDataset` used in chapter 7:

# %%
class PreferenceDataset(Dataset):
    def __init__(
        self,
        data: List[dict],
        tokenizer: Encoding,
    ) -> List[dict]:

        # Store the data
        self.data = data
        self.encoded_texts = self.encode_texts(data, tokenizer)

    def __getitem__(self, index):
        return self.encoded_texts[index]

    def __len__(self):
        return len(self.data)

    def encode_texts(self, data: List[dict], tokenizer: Encoding) -> List[dict]:
        # Pre-tokenize texts
        encoded_texts = []
        for entry in data:
            # Parse and format the entry input as a prompt
            prompt = format_input(entry)
            prompt_tokens = tokenizer.encode(prompt)

            # Parse Chosen text and format it with prompt and tokenize
            chosen_response = entry["chosen"]
            chosen_full_text = f"{prompt}\n\n### Response:\n{chosen_response}"
            chosen_full_tokens = tokenizer.encode(chosen_full_text)

            # Parse Rejected text and format it with prompt and tokenize
            rejected_response = entry["rejected"]
            rejected_full_text = f"{prompt}\n\n### Response:\n{rejected_response}"
            rejected_full_tokens = tokenizer.encode(rejected_full_text)

            # Append the encoded texts to the list
            encoded_texts.append(
                {
                    "prompt": prompt_tokens,
                    "chosen": chosen_full_tokens,
                    "rejected": rejected_full_tokens,
                }
            )
        return encoded_texts

# %% [markdown]
# - Along with an updated `PreferenceDataset` class, we also need an updated batch collation function that we use to pad the sequences in each batch to an equal length so that we can assemble them in batches
# - I added comments to the code below to illustrate the process; however, it might be easiest to understand how it works by looking at the example inputs and outputs further below:

# %%
def custom_collate_fn(
    batch: List[Dict[str, List[int]]],
    pad_token_id: int = 50256,
    allowed_max_length: int = None,
    mask_prompt_tokens: bool = True,
    device: str = "cpu",
):
    """A custom collate function for the DataLoader to pad sequences and create masks."""

    # Initialize lists to hold batch data
    batch_data = {
        "prompt": [],
        "chosen": [],
        "rejected": [],
        "rejected_mask": [],
        "chosen_mask": [],
    }

    # Determine the longest sequence to set a common padding length
    max_length_common = 0
    if batch:
        # Find the maximum length of either chosen or rejected
        for key in ["chosen", "rejected"]:
            current_max = max(len(item[key]) + 1 for item in batch)
            max_length_common = max(max_length_common, current_max)

    # Process each item in the batch
    for item in batch:
        prompt = torch.tensor(item["prompt"])
        batch_data["prompt"].append(prompt)

        for key in ["chosen", "rejected"]:
            # Adjust padding according to the common maximum length
            sequence = item[key]
            padded = sequence + [pad_token_id] * (max_length_common - len(sequence))
            mask = torch.ones(len(padded)).bool()

            # Set mask for all padding tokens to False
            mask[len(sequence) :] = False

            # Set mask for all input tokens to False
            # +2 sets the 2 newline ("\n") tokens before "### Response" to False
            if mask_prompt_tokens:
                mask[: prompt.shape[0] + 2] = False

            batch_data[key].append(torch.tensor(padded))
            batch_data[f"{key}_mask"].append(mask)

    # Final processing
    for key in ["chosen", "rejected", "chosen_mask", "rejected_mask"]:
        # Stack all sequences into a tensor for the given key
        tensor_stack = torch.stack(batch_data[key])

        # Optionally truncate to maximum sequence length
        if allowed_max_length is not None:
            tensor_stack = tensor_stack[:, :allowed_max_length]

        # Move to the specified device
        batch_data[key] = tensor_stack.to(device)

    return batch_data

# %% [markdown]
# - Before we start using the custom collate function, let's make version of it with some of its function arguments prefilled:

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Device:", device)

# partial function allows us to set default values for some arguments
customized_collate_fn = partial(
    custom_collate_fn,
    device=device,  # Put the data directly on a GPU if available
    mask_prompt_tokens=True,  # This is optional
    allowed_max_length=1024,  # The supported context length of the model
)
# Out:
# Device: cuda

# %% [markdown]
# - Now, let's see the `customized_collate_fn` in action and apply it to some sample data from our preference dataset; for this, we take the first two entries:

# %%
example_data = data[:2]

for i in example_data:
    print()
    pprint.pp(i)
# Out:
# {'instruction': 'Evaluate the following phrase by transforming it into the '
#                 'spelling given.',
#  'input': 'freind --> friend',
#  'output': 'The spelling of the given phrase "freind" is incorrect, the '
#            'correct spelling is "friend".',
#  'rejected': 'The spelling of the given phrase "freind" is flat out wrong, get '
#              'it together, the correct spelling is "friend".',
#  'chosen': 'The spelling of the given phrase "freind" is incorrect, the '
#            'correct spelling is "friend".'}
#
# {'instruction': 'Edit the following sentence for grammar.',
#  'input': 'He go to the park every day.',
#  'output': 'He goes to the park every day.',
#  'rejected': 'He goes to the stupid park every single day.',
#  'chosen': 'He goes to the park every day.'}

# %% [markdown]
# - Next, let's instantiate an `example_dataset` and use a PyTorch `DataLoader` to create an `example_dataloader` that mimics the data loader we will use for the model training later:

# %%
tokenizer = tiktoken.get_encoding("gpt2")

example_dataset = PreferenceDataset(example_data, tokenizer)

example_dataloader = DataLoader(
    example_dataset,
    batch_size=2,
    collate_fn=customized_collate_fn,
    shuffle=False,
)

# %% [markdown]
# - The dataset has the following keys:
#
# batch.keys: dict_keys([
#     'prompt',
#     'chosen',
#     'rejected',
#     'rejected_mask',
#     'chosen_mask',
#     ])

# %%
for batch in example_dataloader:
    break

print("batch.keys:", batch.keys())
# Out:
# batch.keys: dict_keys(['prompt', 'chosen', 'rejected', 'rejected_mask', 'chosen_mask'])

# %% [markdown]
# - The prompts are a list of tensors, where each tensor contains the token IDs for a given example
# - Since we selected a batch size of 2, we have two lists of token ID tensors here:

# %%
batch["prompt"]
# Out:
# [tensor([21106,   318,   281, 12064,   326,  8477,   257,  4876,    13, 19430,
#            257,  2882,   326, 20431, 32543,   262,  2581,    13,   198,   198,
#          21017, 46486,    25,   198,    36,  2100,  4985,   262,  1708,  9546,
#            416, 25449,   340,   656,   262, 24993,  1813,    13,   198,   198,
#          21017, 23412,    25,   198, 19503,   521, 14610,  1545]),
#  tensor([21106,   318,   281, 12064,   326,  8477,   257,  4876,    13, 19430,
#            257,  2882,   326, 20431, 32543,   262,  2581,    13,   198,   198,
#          21017, 46486,    25,   198, 18378,   262,  1708,  6827,   329, 23491,
#             13,   198,   198, 21017, 23412,    25,   198,  1544,   467,   284,
#            262,  3952,   790,  1110,    13])]

# %% [markdown]
# - We don't really need the responses for training; what we need to feed to the model during training are the `"chosen"` and `"rejected"` entries
# - The  `"chosen"` and `"rejected"` response entries are padded so that we can stack them as tensors; similar to the prompts, these response texts are encoded into token IDs:

# %%
batch["chosen"]
# Out:
# tensor([[21106,   318,   281, 12064,   326,  8477,   257,  4876,    13, 19430,
#            257,  2882,   326, 20431, 32543,   262,  2581,    13,   198,   198,
#          21017, 46486,    25,   198,    36,  2100,  4985,   262,  1708,  9546,
#            416, 25449,   340,   656,   262, 24993,  1813,    13,   198,   198,
#          21017, 23412,    25,   198, 19503,   521, 14610,  1545,   198,   198,
#          21017, 18261,    25,   198,   464, 24993,   286,   262,  1813,  9546,
#            366, 19503,   521,     1,   318, 11491,    11,   262,  3376, 24993,
#            318,   366,  6726,  1911, 50256, 50256, 50256, 50256, 50256, 50256,
#          50256],
#         [21106,   318,   281, 12064,   326,  8477,   257,  4876,    13, 19430,
#            257,  2882,   326, 20431, 32543,   262,  2581,    13,   198,   198,
#          21017, 46486,    25,   198, 18378,   262,  1708,  6827,   329, 23491,
#             13,   198,   198, 21017, 23412,    25,   198,  1544,   467,   284,
#            262,  3952,   790,  1110,    13,   198,   198, 21017, 18261,    25,
#            198,  1544,  2925,   284,   262,  3952,   790,  1110,    13, 50256,
#          50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256,
#          50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256,
#          50256]], device='cuda:0')

# %% [markdown]
# ### 2.4.1 Tokenizing the data
# - The token IDs above represent the model inputs, but in this format, they are hard to interpret for us humans
# - So, let's implement a small utility function to convert them back into text so that we can inspect and interpret them more easily:

# %%
def text_to_token_ids(
    text: str,
    tokenizer: Encoding,
) -> torch.Tensor:
    encoded = tokenizer.encode(text, allowed_special={"<|endoftext|>"})
    encoded_tensor = torch.tensor(encoded).unsqueeze(0)  # add batch dimension
    return encoded_tensor

# %%
def token_ids_to_text(
    token_ids: torch.Tensor,
    tokenizer: Encoding,
) -> List[str]:
    """Flatten and decode token IDs to text."""
    ids_in_python_list = token_ids.flatten().tolist()
    return tokenizer.decode(ids_in_python_list)

# %% [markdown]
# - Let's apply the `decode_tokens_from_batch` utility function to the first prompt entry in the batch:

# %%
text = token_ids_to_text(
    token_ids=batch["prompt"][0],  # [0] for the first entry in the batch
    tokenizer=tokenizer,
)
print(text)
# Out:
# Below is an instruction that describes a task. Write a response that appropriately completes the request.
#
# ### Instruction:
# Evaluate the following phrase by transforming it into the spelling given.
#
# ### Input:
# freind --> friend

# %% [markdown]
# - As we can see above, the prompt was correctly formatted; let's now do the same for the `"chosen"` response:

# %%
text = token_ids_to_text(
    token_ids=batch["chosen"][0],
    tokenizer=tokenizer,
)
print(text)
# Out:
# Below is an instruction that describes a task. Write a response that appropriately completes the request.
#
# ### Instruction:
# Evaluate the following phrase by transforming it into the spelling given.
#
# ### Input:
# freind --> friend
#
# ### Response:
# The spelling of the given phrase "freind" is incorrect, the correct spelling is "friend".<|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|><|endoftext|>

# %% [markdown]
# - As we can see above, similar to instruction finetuning, the response that is passed to the model during training also contains the input prompt
# - Also note that we included `<|endoftext|>` tokens as padding tokens, which are necessary so that we can extend the responses to a similar length to stack them as a batch
# - Don't worry; the `<|endoftext|>` tokens will be ignored in the loss later so that they won't affect the training outcome
# - Let's now also inspect the corresponding rejected response:

# %%
text = token_ids_to_text(
    token_ids=batch["rejected"][0],
    tokenizer=tokenizer,
)
print(text)
# Out:
# Below is an instruction that describes a task. Write a response that appropriately completes the request.
#
# ### Instruction:
# Evaluate the following phrase by transforming it into the spelling given.
#
# ### Input:
# freind --> friend
#
# ### Response:
# The spelling of the given phrase "freind" is flat out wrong, get it together, the correct spelling is "friend".<|endoftext|>

# %% [markdown]
# - In this case, as we can see above, the rejected response is a more impolite version of the chosen response (we don't want the model to generate impolite responses)
# - Lastly, let's talk about the data masks: if you took a closer look at our custom collate function we implemented above, we created a `"chosen_mask"` and a `"rejected_mask"` for each dataset entry
# - The masks have the same shape as the response entries, as shown below for the `"chosen"` entry:

# %%
print("chosen inputs:", batch["chosen"][0].shape)
print("chosen mask:  ", batch["chosen_mask"][0].shape)
# Out:
# chosen inputs: torch.Size([81])
# chosen mask:   torch.Size([81])

# %% [markdown]
# - The contents of these masks are boolean (`True` and `False`) values:

# %%
batch["chosen_mask"][0]
# Out:
# tensor([False, False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False, False,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True, False, False, False, False, False, False,
#         False], device='cuda:0')

# %%
batch["rejected_mask"][0]
# Out:
# tensor([False, False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False, False,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,  True,
#         False], device='cuda:0')

# %% [markdown]
# - The `True` values denote token IDs that correspond to the actual response
# - the `False` tokens correspond to token IDs that correspond to either prompt tokens (if we set `mask_prompt_tokens=True` in the `customized_collate_fn` function, which we previously did) or padding tokens
# - Hence, we can use the mask as a selection mask to select only the token IDs that correspond to the response, that is, stripping all prompt and padding tokens, as we can see below:

# %%
text = token_ids_to_text(
    token_ids=batch["chosen"][0][batch["chosen_mask"][0]],
    tokenizer=tokenizer,
)
print(text)
# Out:
# ### Response:
# The spelling of the given phrase "freind" is incorrect, the correct spelling is "friend".

# %%
text = token_ids_to_text(
    token_ids=batch["rejected"][0][batch["rejected_mask"][0]],
    tokenizer=tokenizer,
)
print(text)
# Out:
# ### Response:
# The spelling of the given phrase "freind" is flat out wrong, get it together, the correct spelling is "friend".

# %% [markdown]
# - We will make use of this mask to ignore prompt and padding tokens when computing the DPO loss later

# %% [markdown]
# ### 2.5 Creating training, validation, and test set data loaders

# %% [markdown]
# - Above, we worked with a small example subsets from the preference dataset for illustration purposes
# - Let's now create the actual training, validation, and test set data loaders
# - This process is identical to creating the data loaders in the pretraining and instruction finetuning chapters and thus should be self-explanatory

# %%
torch.manual_seed(123)

# %%
num_workers = 0
batch_size = 8

train_dataset = PreferenceDataset(train_data, tokenizer)
val_dataset = PreferenceDataset(val_data, tokenizer)
test_dataset = PreferenceDataset(test_data, tokenizer)

# %%
train_loader = DataLoader(
    train_dataset,
    batch_size=batch_size,
    collate_fn=customized_collate_fn,
    shuffle=True,
    drop_last=True,
    num_workers=num_workers,
)

val_loader = DataLoader(
    val_dataset,
    batch_size=batch_size,
    collate_fn=customized_collate_fn,
    shuffle=False,
    drop_last=False,
    num_workers=num_workers,
)

test_loader = DataLoader(
    test_dataset,
    batch_size=batch_size,
    collate_fn=customized_collate_fn,
    shuffle=False,
    drop_last=False,
    num_workers=num_workers,
)

# %% [markdown]
# * Let's iterate over the first batch of the training data loader to see if everything is working as expected:

# %% [markdown]
# - Let's iterate through the data loader and take a look at the dataset shapes:

# %%
print("Train loader:")
n = 0
for i, batch in enumerate(train_loader):
    print(
        batch["chosen"].shape,
        batch["rejected"].shape,
    )
# Out:
# Train loader:
# torch.Size([8, 77]) torch.Size([8, 77])
# torch.Size([8, 81]) torch.Size([8, 81])
# torch.Size([8, 94]) torch.Size([8, 94])
# torch.Size([8, 75]) torch.Size([8, 75])
# torch.Size([8, 75]) torch.Size([8, 75])
# torch.Size([8, 76]) torch.Size([8, 76])
# torch.Size([8, 99]) torch.Size([8, 99])
# torch.Size([8, 71]) torch.Size([8, 71])
# torch.Size([8, 67]) torch.Size([8, 67])
# torch.Size([8, 88]) torch.Size([8, 88])
# torch.Size([8, 65]) torch.Size([8, 65])
# torch.Size([8, 79]) torch.Size([8, 79])
# torch.Size([8, 80]) torch.Size([8, 80])
# torch.Size([8, 97]) torch.Size([8, 97])
# torch.Size([8, 71]) torch.Size([8, 71])
# torch.Size([8, 89]) torch.Size([8, 89])
# torch.Size([8, 75]) torch.Size([8, 75])
# torch.Size([8, 69]) torch.Size([8, 69])
# torch.Size([8, 84]) torch.Size([8, 84])
# torch.Size([8, 79]) torch.Size([8, 79])
# torch.Size([8, 101]) torch.Size([8, 101])
# torch.Size([8, 87]) torch.Size([8, 87])
# torch.Size([8, 73]) torch.Size([8, 73])
# torch.Size([8, 69]) torch.Size([8, 69])
# torch.Size([8, 80]) torch.Size([8, 80])
# torch.Size([8, 68]) torch.Size([8, 68])
# torch.Size([8, 73]) torch.Size([8, 73])
# torch.Size([8, 71]) torch.Size([8, 71])
# torch.Size([8, 91]) torch.Size([8, 91])
# torch.Size([8, 78]) torch.Size([8, 78])
# torch.Size([8, 78]) torch.Size([8, 78])
# torch.Size([8, 71]) torch.Size([8, 71])
# torch.Size([8, 84]) torch.Size([8, 84])
# torch.Size([8, 92]) torch.Size([8, 92])
# torch.Size([8, 71]) torch.Size([8, 71])
# torch.Size([8, 66]) torch.Size([8, 66])
# torch.Size([8, 73]) torch.Size([8, 73])
# torch.Size([8, 73]) torch.Size([8, 73])
# torch.Size([8, 78]) torch.Size([8, 78])
# torch.Size([8, 66]) torch.Size([8, 66])
# torch.Size([8, 76]) torch.Size([8, 76])
# torch.Size([8, 100]) torch.Size([8, 100])
# torch.Size([8, 77]) torch.Size([8, 77])
# torch.Size([8, 92]) torch.Size([8, 92])
# torch.Size([8, 93]) torch.Size([8, 93])
# torch.Size([8, 115]) torch.Size([8, 115])
# torch.Size([8, 81]) torch.Size([8, 81])
# torch.Size([8, 95]) torch.Size([8, 95])
# torch.Size([8, 81]) torch.Size([8, 81])
# torch.Size([8, 94]) torch.Size([8, 94])
# torch.Size([8, 70]) torch.Size([8, 70])
# torch.Size([8, 89]) torch.Size([8, 89])
# torch.Size([8, 90]) torch.Size([8, 90])
# torch.Size([8, 70]) torch.Size([8, 70])
# torch.Size([8, 85]) torch.Size([8, 85])
# torch.Size([8, 65]) torch.Size([8, 65])
# torch.Size([8, 76]) torch.Size([8, 76])
# torch.Size([8, 72]) torch.Size([8, 72])
# torch.Size([8, 84]) torch.Size([8, 84])
# torch.Size([8, 84]) torch.Size([8, 84])
# torch.Size([8, 65]) torch.Size([8, 65])
# torch.Size([8, 63]) torch.Size([8, 63])
# torch.Size([8, 74]) torch.Size([8, 74])
# torch.Size([8, 79]) torch.Size([8, 79])
# torch.Size([8, 93]) torch.Size([8, 93])
# torch.Size([8, 71]) torch.Size([8, 71])
# torch.Size([8, 99]) torch.Size([8, 99])
# torch.Size([8, 81]) torch.Size([8, 81])
# torch.Size([8, 77]) torch.Size([8, 77])
# torch.Size([8, 74]) torch.Size([8, 74])
# torch.Size([8, 75]) torch.Size([8, 75])
# torch.Size([8, 73]) torch.Size([8, 73])
# torch.Size([8, 87]) torch.Size([8, 87])
# torch.Size([8, 80]) torch.Size([8, 80])
# torch.Size([8, 75]) torch.Size([8, 75])
# torch.Size([8, 81]) torch.Size([8, 81])
# torch.Size([8, 86]) torch.Size([8, 86])
# torch.Size([8, 71]) torch.Size([8, 71])
# torch.Size([8, 63]) torch.Size([8, 63])
# torch.Size([8, 82]) torch.Size([8, 82])
# torch.Size([8, 68]) torch.Size([8, 68])
# torch.Size([8, 76]) torch.Size([8, 76])
# torch.Size([8, 68]) torch.Size([8, 68])
# torch.Size([8, 97]) torch.Size([8, 97])
# torch.Size([8, 72]) torch.Size([8, 72])
# torch.Size([8, 85]) torch.Size([8, 85])
# torch.Size([8, 67]) torch.Size([8, 67])
# torch.Size([8, 85]) torch.Size([8, 85])
# torch.Size([8, 87]) torch.Size([8, 87])
# torch.Size([8, 76]) torch.Size([8, 76])
# torch.Size([8, 74]) torch.Size([8, 74])
# torch.Size([8, 92]) torch.Size([8, 92])
# torch.Size([8, 85]) torch.Size([8, 85])
# torch.Size([8, 72]) torch.Size([8, 72])
# torch.Size([8, 93]) torch.Size([8, 93])
# torch.Size([8, 82]) torch.Size([8, 82])
# torch.Size([8, 76]) torch.Size([8, 76])
# torch.Size([8, 93]) torch.Size([8, 93])
# torch.Size([8, 80]) torch.Size([8, 80])
# torch.Size([8, 87]) torch.Size([8, 87])
# torch.Size([8, 69]) torch.Size([8, 69])
# torch.Size([8, 90]) torch.Size([8, 90])
# torch.Size([8, 99]) torch.Size([8, 99])
# torch.Size([8, 104]) torch.Size([8, 104])
# torch.Size([8, 101]) torch.Size([8, 101])
# torch.Size([8, 98]) torch.Size([8, 98])
# torch.Size([8, 79]) torch.Size([8, 79])
# torch.Size([8, 71]) torch.Size([8, 71])
# torch.Size([8, 76]) torch.Size([8, 76])
# torch.Size([8, 79]) torch.Size([8, 79])
# torch.Size([8, 79]) torch.Size([8, 79])
# torch.Size([8, 67]) torch.Size([8, 67])
# torch.Size([8, 84]) torch.Size([8, 84])
# torch.Size([8, 78]) torch.Size([8, 78])
# torch.Size([8, 85]) torch.Size([8, 85])
# torch.Size([8, 70]) torch.Size([8, 70])

# %% [markdown]
# - Each row shows the shape of the `"chosen"` and `"rejected"` entries in each batch
# - Since we applied padding on a batch-by-batch basis using the custom_collate_fn, each row has a different shape
# - This is for efficiency reasons because it would be inefficient to pad all samples to the longest sample in the whole dataset

# %% [markdown]
# &nbsp;
# # 3) Loading a finetuned LLM for DPO alignment

# %% [markdown]
# - LLM alignment steps, such as RLHF or DPO, assume that we already have an instruction-finetuned model
# - This section contains minimal code to load the model that was instruction finetuned and saved in chapter 7 (via [../01_main-chapter-code/ch07.ipynb](../01_main-chapter-code/ch07.ipynb))
# - Make sure you run the chapter 7 code first to create the instruction-finetuned model before you proceed
# - The code below will copy the instruction-finetuned model into the current directory:

# %%
def generate_text_simple(
    model: GPT2LMHeadModel,
    input_ids: torch.LongTensor,
    max_new_tokens: int,
    context_window_size: int,
) -> torch.LongTensor:
    """Generate text by iteratively predicting the next token."""

    # Initialize the generated sequence with the input IDs
    generated_sequence = input_ids

    for _ in range(max_new_tokens):
        # Extract the last `context_window_size` tokens as the context for prediction
        context_input_ids = generated_sequence[:, -context_window_size:]

        with torch.no_grad():
            # Forward pass through the model to get the logits
            model_outputs = model(context_input_ids)
            logits = model_outputs.logits

        # Focus on the logits of the last token in the sequence
        last_token_logits = logits[:, -1, :]

        # Select the token with the highest probability (greedy decoding)
        next_token_id = torch.argmax(last_token_logits, dim=-1, keepdim=True)

        # Append the selected token to the sequence
        generated_sequence = torch.cat((generated_sequence, next_token_id), dim=1)

    return generated_sequence


def generate(
    model: GPT2LMHeadModel,
    input_ids: torch.LongTensor,
    max_length: int = 50,
    context_window_size: int = 1024,
    temperature: float = 1.0,
    top_k: Optional[int] = None,
    eos_token_id: Optional[int] = None,
) -> torch.LongTensor:
    """Generate text using the model."""

    # Initialize the generated sequence with the input IDs
    generated_sequence = input_ids

    for _ in range(max_length):
        # Extract the last `context_window_size` tokens as the context for prediction
        context_input_ids = generated_sequence[:, -context_window_size:]

        with torch.no_grad():
            # Forward pass through the model to get the logits
            model_outputs = model(context_input_ids)
            logits = model_outputs.logits

        # Focus on the logits of the last token in the sequence
        last_token_logits = logits[:, -1, :]

        # Apply top-k filtering if specified
        if top_k is not None:
            # Retain only the top_k logits
            top_k_logits, top_k_indices = torch.topk(last_token_logits, top_k)
            filtered_logits = torch.full_like(
                last_token_logits, float("-inf")
            ).scatter_(1, top_k_indices, top_k_logits)
            last_token_logits = filtered_logits

        # Apply temperature scaling if specified
        if temperature != 1.0:
            last_token_logits = last_token_logits / temperature

        # Convert logits to probabilities
        token_probabilities = torch.softmax(last_token_logits, dim=-1)

        # Sample the next token from the probability distribution
        next_token_id = torch.multinomial(token_probabilities, num_samples=1)

        # Stop if the end-of-sequence token is generated and `eos_token_id` is specified
        if eos_token_id is not None and next_token_id.item() == eos_token_id:
            break

        # Append the generated token to the sequence
        generated_sequence = torch.cat((generated_sequence, next_token_id), dim=1)

    return generated_sequence

# %%
def generate_sample(
    model: GPT2LMHeadModel,
    tokenizer: Encoding,
    device: torch.device,
    start_context: str,
    max_new_tokens: int = 50,
) -> None:
    """Generate and print a sample of text using the provided model and tokenizer."""

    # Set the model to evaluation mode
    model.eval()

    # Get the context size from the model's positional embeddings
    context_window_size = model.config.n_positions

    # Encode the starting context text to token IDs
    encoded_input = text_to_token_ids(start_context, tokenizer).to(device)

    with torch.no_grad():
        # Generate token IDs for the new tokens
        generated_token_ids = generate_text_simple(
            model=model,
            input_ids=encoded_input,
            max_new_tokens=max_new_tokens,
            context_window_size=context_window_size,
        )

        # Decode the token IDs to text
        generated_text = token_ids_to_text(generated_token_ids, tokenizer)

        # Print the generated text with newline characters replaced by spaces
        print(generated_text.replace("\n", " "))

    # Set the model back to training mode
    model.train()

# %%
def extract_response(
    response_text: str,
    input_text: str,
) -> str:
    """Extract the response text from the model output."""
    return response_text[len(input_text) :].replace("### Response:", "").strip()

# %%
def plot_losses(
    epochs_seen: torch.LongTensor,
    tokens_seen: torch.LongTensor,
    train_losses: torch.FloatTensor,
    val_losses: torch.FloatTensor,
    label: str = "loss",
):
    fig, ax1 = plt.subplots(figsize=(5, 3))

    # Plot training and validation loss against epochs
    ax1.plot(epochs_seen, train_losses, label=f"Training {label}")
    ax1.plot(epochs_seen, val_losses, linestyle="-.", label=f"Validation {label}")
    ax1.set_xlabel("Epochs")
    ax1.set_ylabel(label.capitalize())
    ax1.legend()
    ax1.xaxis.set_major_locator(
        MaxNLocator(integer=True)
    )  # only show integer labels on x-axis

    # Create a second x-axis for tokens seen
    ax2 = ax1.twiny()  # Create a second x-axis that shares the same y-axis
    ax2.plot(tokens_seen, train_losses, alpha=0)  # Invisible plot for aligning ticks
    ax2.set_xlabel("Tokens seen")

    fig.tight_layout()  # Adjust layout to make room for the second x-axis
    plt.show()

# %% [markdown]
# ### 3.1 Load the model

# %%
# Load a pre-trained GPT-2 model (e.g., 'gpt2-medium')
model = GPT2LMHeadModel.from_pretrained("gpt2-medium")

# Access the model's configuration
config = model.config

# Print the configuration to keep track of the architecture
print(config)
# Out:
# GPT2Config {
#   "_name_or_path": "gpt2-medium",
#   "activation_function": "gelu_new",
#   "architectures": [
#     "GPT2LMHeadModel"
#   ],
#   "attn_pdrop": 0.1,
#   "bos_token_id": 50256,
#   "embd_pdrop": 0.1,
#   "eos_token_id": 50256,
#   "initializer_range": 0.02,
#   "layer_norm_epsilon": 1e-05,
#   "model_type": "gpt2",
#   "n_ctx": 1024,
#   "n_embd": 1024,
#   "n_head": 16,
#   "n_inner": null,
#   "n_layer": 24,
#   "n_positions": 1024,
#   "n_special": 0,
#   "predict_special_tokens": true,
#   "reorder_and_upcast_attn": false,
#   "resid_pdrop": 0.1,
#   "scale_attn_by_inverse_layer_idx": false,
#   "scale_attn_weights": true,
#   "summary_activation": null,
#   "summary_first_dropout": 0.1,
#   "summary_proj_to_labels": true,
#   "summary_type": "cls_index",
#   "summary_use_proj": true,
#   "task_specific_params": {
#     "text-generation": {
#       "do_sample": true,
#       "max_length": 50
#     }
#   },
#   "transformers_version": "4.38.2",
#   "use_cache": true,
#   "vocab_size": 50257
# }

# %% [markdown]
# - Before training the loaded model with DPO, let's make sure that the finetuned model was saved and loaded correctly by trying it out on some sample data:

# %%
prompt = """Below is an instruction that describes a task. Write a response
that appropriately completes the request.

### Instruction:
Convert the active sentence to passive: 'The chef cooks the meal every day.'
"""

# %%
torch.manual_seed(123)

token_ids = generate(
    model=model,
    input_ids=text_to_token_ids(prompt, tokenizer),
    max_length=35,
    context_window_size=config.n_embd,
    eos_token_id=50256,
)

response = token_ids_to_text(token_ids, tokenizer)
print(response)
# Out:
# Below is an instruction that describes a task. Write a response
# that appropriately completes the request.
#
# ### Instruction:
# Convert the active sentence to passive: 'The chef cooks the meal every day.'
#
# Update a response with a spell from the active sentence
#
# Create an action trigger that is passed to both reflex and the default response
#
# Create a step action trigger that

# %% [markdown]
# - As we can see above, the model gives a reasonable and correct response
# - As explained in chapter 7, in practice, we would clean up the response to only return the response text with the prompt and prompt style removed (similar to what you are familiar with from ChatGPT, for example):

# %%
# Extract the response from the model output
response = extract_response(response, prompt)
print(response)
# Out:
# Update a response with a spell from the active sentence
#
# Create an action trigger that is passed to both reflex and the default response
#
# Create a step action trigger that

# %% [markdown]
# - Now, we are almost ready to get to the DPO part
# - As mentioned at the beginning of this notebook, DPO works with two LLMs: a policy model (the LLM that we want to optimize) and a reference model (the original model that we keep unchanged)
# - Below, we rename the `model` as `policy_model` and instantiate a second instance of the model we refer to as the `reference_model`

# %% [markdown]
# ### 3.2 Instantiate the policy and reference models

# %%
# Set up the policy model from the GPT-2 model
policy_model = model

# %%
# Set up the reference model from the GPT-2 model
reference_model = GPT2LMHeadModel.from_pretrained("gpt2-medium")
reference_model.eval()
# Out:
# GPT2LMHeadModel(
#   (transformer): GPT2Model(
#     (wte): Embedding(50257, 1024)
#     (wpe): Embedding(1024, 1024)
#     (drop): Dropout(p=0.1, inplace=False)
#     (h): ModuleList(
#       (0-23): 24 x GPT2Block(
#         (ln_1): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (attn): GPT2Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (mlp): GPT2MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (act): NewGELUActivation()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#     )
#     (ln_f): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#   )
#   (lm_head): Linear(in_features=1024, out_features=50257, bias=False)
# )

# %%
# Move the models to the specified device
policy_model.to(device)
reference_model.to(device)
# Out:
# GPT2LMHeadModel(
#   (transformer): GPT2Model(
#     (wte): Embedding(50257, 1024)
#     (wpe): Embedding(1024, 1024)
#     (drop): Dropout(p=0.1, inplace=False)
#     (h): ModuleList(
#       (0-23): 24 x GPT2Block(
#         (ln_1): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (attn): GPT2Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (mlp): GPT2MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (act): NewGELUActivation()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#     )
#     (ln_f): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#   )
#   (lm_head): Linear(in_features=1024, out_features=50257, bias=False)
# )

# %% [markdown]
# &nbsp;
# # 4) Coding the DPO Loss Function

# %% [markdown]
# - After we took care of the model loading and dataset preparation in the previous sections, we can now get to the fun part and code the DPO loss
# - Note that the DPO loss code below is based on the method proposed in the [Direct Preference Optimization: Your Language Model is Secretly a Reward Model](https://arxiv.org/abs/2305.18290) paper
# - For reference, the core DPO equation is shown again below:
#
# <img src="https://sebastianraschka.com/images/LLMs-from-scratch-images/dpo/3.webp?123" width=800px>
#
# - In the equation above,
#   - "expected value" $\mathbb{E}$ is statistics jargon and stands for the average or mean value of the random variable (the expression inside the brackets); optimizing $-\mathbb{E}$ aligns the model better with user preferences
#   - The $\pi_{\theta}$ variable is the so-called policy (a term borrowed from reinforcement learning) and represents the LLM we want to optimize; $\pi_{ref}$ is a reference LLM, which is typically the original LLM before optimization (at the beginning of the training, $\pi_{\theta}$ and $\pi_{ref}$ are typically the same)
#   - $\beta$ is a hyperparameter to control the divergence between the $\pi_{\theta}$ and the reference model; increasing $\beta$ increases the impact of the difference between
# $\pi_{\theta}$ and $\pi_{ref}$ in terms of their log probabilities on the overall loss function, thereby increasing the divergence between the two models
#   - the logistic sigmoid function, $\sigma(\centerdot)$ transforms the log-odds of the preferred and rejected responses (the terms inside the logistic sigmoid function) into a probability score
# - To avoid bloating the code notebook with a more detailed discussion, I may write a separate standalone article with more details on these concepts in the future
# - In the meantime, if you are interested in comparing RLHF and DPO, please see the section [2.2. RLHF vs Direct Preference Optimization (DPO)](https://magazine.sebastianraschka.com/i/142924793/rlhf-vs-direct-preference-optimization-dpo) in my article [Tips for LLM Pretraining and Evaluating Reward Models](https://magazine.sebastianraschka.com/p/tips-for-llm-pretraining-and-evaluating-rms)

# %%
def compute_dpo_loss(
    model_chosen_logprobs: torch.FloatTensor,
    model_rejected_logprobs: torch.FloatTensor,
    reference_chosen_logprobs: torch.FloatTensor,
    reference_rejected_logprobs: torch.FloatTensor,
    beta: float = 0.1,
):
    """Compute the DPO loss for a batch of policy and reference model log probabilities.

    Args:
        policy_chosen_logprobs: Log probabilities of the policy model for the chosen responses. Shape: (batch_size,)
        policy_rejected_logprobs: Log probabilities of the policy model for the rejected responses. Shape: (batch_size,)
        reference_chosen_logprobs: Log probabilities of the reference model for the chosen responses. Shape: (batch_size,)
        reference_rejected_logprobs: Log probabilities of the reference model for the rejected responses. Shape: (batch_size,)
        beta: Temperature parameter for the DPO loss; typically something in the range of 0.1 to 0.5. We ignore the reference model as beta -> 0.
        label_smoothing: conservativeness for DPO loss.

    Returns:
        A tuple of three tensors: (loss, chosen_rewards, rejected_rewards).
    """
    # Compute the log-ratios
    model_logratios = model_chosen_logprobs - model_rejected_logprobs
    reference_logratios = reference_chosen_logprobs - reference_rejected_logprobs
    logits = model_logratios - reference_logratios

    # DPO (Eq. 7 of https://arxiv.org/pdf/2305.18290.pdf)
    losses = -F.logsigmoid(beta * logits)

    # Optional values to track progress during training
    chosen_rewards = (model_chosen_logprobs - reference_chosen_logprobs).detach()
    rejected_rewards = (model_rejected_logprobs - reference_rejected_logprobs).detach()

    # .mean() to average over the samples in the batch
    return losses.mean(), chosen_rewards.mean(), rejected_rewards.mean()

# %% [markdown]
# - If you are familiar with logarithms, note that we have the general relationship $\log\left(\frac{a}{b}\right) = \log a - \log b$, which we applied in the code above
# - Keeping this in mind, let's go through some of the steps (we will calculate the `logprobs` using a separate function later)
# - Let's start with the lines
#
#     ```python
#     model_logratios = model_chosen_logprobs - model_rejected_logprobs
#     reference_logratios = reference_chosen_logprobs - reference_rejected_logprobs
#     ```
#
# - These lines above calculate the difference in log probabilities (logits) for the chosen and rejected samples for both the policy model and the reference model (this is due to $\log\left(\frac{a}{b}\right) = \log a - \log b$):
#
# $$\log \left( \frac{\pi_\theta (y_w \mid x)}{\pi_\theta (y_l \mid x)} \right) \quad \text{and} \quad \log \left( \frac{\pi_{\text{ref}}(y_w \mid x)}{\pi_{\text{ref}}(y_l \mid x)} \right)$$

# %% [markdown]
# - Next, the code `logits = model_logratios - reference_logratios` computes the difference between the model's log ratios and the reference model's log ratios, i.e.,
#
# $$\beta \log \left( \frac{\pi_\theta (y_w \mid x)}{\pi_{\text{ref}} (y_w \mid x)} \right)
# - \beta \log \left( \frac{\pi_\theta (y_l \mid x)}{\pi_{\text{ref}} (y_l \mid x)} \right)$$

# %% [markdown]
# - Finally, `losses = -F.logsigmoid(beta * logits)`  calculates the loss using the log-sigmoid function; in the original equation, the term inside the expectation is
#
# $$\log \sigma \left( \beta \log \left( \frac{\pi_\theta (y_w \mid x)}{\pi_{\text{ref}} (y_w \mid x)} \right)
# - \beta \log \left( \frac{\pi_\theta (y_l \mid x)}{\pi_{\text{ref}} (y_l \mid x)} \right) \right)$$

# %% [markdown]
# ### 4.1 Implementing probability loss calculation
#
# - Above, we assumed that the log probabilities were already computed; let's now define a `compute_logprobs` function that we can use to compute these log probabilities that were passed into the `compute_dpo_loss` function above, that is, the values $\pi_\theta (y_w \mid x)$, ${\pi_\theta (y_l \mid x)}$, and so forth:

# %%
def compute_logprobs(
    logits: torch.FloatTensor,
    labels: torch.LongTensor,
    selection_mask: Optional[torch.LongTensor] = None,
) -> torch.FloatTensor:
    """
    Compute log probabilities.

    Args:
      logits: Tensor of shape (batch_size, num_tokens, vocab_size)
      labels: Tensor of shape (batch_size, num_tokens)
      selection_mask: Tensor for shape (batch_size, num_tokens)

    Returns:
      mean_log_prob: Mean log probability excluding padding tokens.
    """

    # Labels are the inputs shifted by one
    # Shape: (batch_size, num_tokens)
    labels = labels[:, 1:].clone()

    # Truncate logits to match the labels num_tokens
    # Remove padding tokens from the logits
    # Shape: (batch_size, num_tokens, vocab_size)
    logits = logits[:, :-1, :]

    # Compute log probabilities
    log_probs = F.log_softmax(logits, dim=-1)

    # Gather the log probabilities for the actual labels
    # extract the log probabilities corresponding to the correct labels
    selected_log_probs = torch.gather(
        input=log_probs, dim=-1, index=labels.unsqueeze(-1)
    ).squeeze(-1)

    # Apply the selection mask to filter out padding tokens and template tokens
    if selection_mask is None:
        mask = selection_mask[:, 1:].clone()

        # Apply the mask to filter out padding tokens
        selected_log_probs = selected_log_probs * mask

        # Calculate the average log probability excluding padding tokens
        # This averages over the tokens, so the shape is (batch_size, num_tokens)
        avg_log_prob = selected_log_probs.sum(-1) / mask.sum(-1)

        return avg_log_prob

    else:
        return selected_log_probs.mean(-1)

# %% [markdown]
# - Note that this function above might look a bit intimidating at first due to the `torch.gather` function, but it's pretty similar to what happens under the hood in PyTorch's `cross_entropy` function
# - For example, consider the following example:

# %%
# Sample data
logits = torch.tensor([[2.0, 1.0, 0.1], [0.5, 2.5, 0.3]])  # Shape: (2, 3)
targets = torch.tensor([0, 2])  # Shape: (2,)


# Manual loss using torch.gather
log_softmax_logits = F.log_softmax(logits, dim=1)  # Shape: (2, 3)
selected_log_probs = torch.gather(
    input=log_softmax_logits,
    dim=1,
    index=targets.unsqueeze(1),  # Shape 2, 1
).squeeze(
    1
)  # Shape: (2,)
manual_loss = -selected_log_probs.mean()  # Averaging over the batch


# PyTorch loss
cross_entropy_loss = F.cross_entropy(logits, targets)

print(manual_loss, cross_entropy_loss)
# Out:
# tensor(1.4185) tensor(1.4185)

# %% [markdown]
# - So, above, we can see that the two implementations are equivalent, but let's narrow down a bit further to the `torch.gather` mechanics
# - Consider the following two tensors:

# %%
t = torch.tensor(
    [
        [1.0, 2.0],
        [3.0, 4.0],
    ]
)

m = torch.tensor([[1, 1], [0, 1]])

# %% [markdown]
# - Above, `t` is a tensor we want to select from, and `m` is a mask to specify how we want to select
#  - For instance, since `m` contains `[1, 1]` n the first row, it will select two times the value of `t` in index position `1`, which is the value 2.
#  - The second row of `m`, `[0, 1]`, selects index positions 0 and 1 in the second row or `t`, which are `3.` and `4.`

# %%
torch.gather(input=t, dim=-1, index=m)
# Out:
# tensor([[2., 2.],
#         [3., 4.]])

# %% [markdown]
# - In other words, `torch.gather` is a selection function
# - When we computed the loss earlier, we used it to retrieve the log probabilities corresponding to the correct token in the 50,256-token vocabulary
# - The "correct" tokens are the tokens given in the response entry

# %% [markdown]
# - Regarding the `compute_logprobs` function above, we use `torch.gather` here because it gives us a bit more control than `cross_entropy`, but is, in essence, a similar idea
# - The `selection_mask` we use there is to optionally ignore prompt and padding tokens
# - We can then use the `compute_logprobs` function as follows to compute the inputs for the `compute_dpo_loss` loss function

# %%
def compute_dpo_loss_batch(
    batch: Dict[str, torch.LongTensor],
    policy_model: GPT2LMHeadModel,
    reference_model: GPT2LMHeadModel,
    beta: float,
):
    """Compute the DPO loss on an input batch"""

    # where policy_model(batch["chosen"]) are the logits
    policy_chosen_log_probas = compute_logprobs(
        logits=policy_model(batch["chosen"]).logits,
        labels=batch["chosen"],
        selection_mask=batch["chosen_mask"],
    )
    policy_rejected_log_probas = compute_logprobs(
        logits=policy_model(batch["rejected"]).logits,
        labels=batch["rejected"],
        selection_mask=batch["rejected_mask"],
    )
    ref_chosen_log_probas = compute_logprobs(
        logits=reference_model(batch["chosen"]).logits,
        labels=batch["chosen"],
        selection_mask=batch["chosen_mask"],
    )
    ref_rejected_log_probas = compute_logprobs(
        logits=reference_model(batch["rejected"]).logits,
        labels=batch["rejected"],
        selection_mask=batch["rejected_mask"],
    )
    loss, chosen_rewards, rejected_rewards = compute_dpo_loss(
        model_chosen_logprobs=policy_chosen_log_probas,
        model_rejected_logprobs=policy_rejected_log_probas,
        reference_chosen_logprobs=ref_chosen_log_probas,
        reference_rejected_logprobs=ref_rejected_log_probas,
        beta=beta,
    )
    return loss, chosen_rewards, rejected_rewards

# %% [markdown]
# - The above function works for a single batch, for example:

# %%
with torch.no_grad():
    loss = compute_dpo_loss_batch(
        batch,
        policy_model,
        reference_model,
        beta=0.1,
    )
print(
    f"Loss: {loss[0]:.4f}, Chosen rewards: {loss[1]:.4f}, Rejected rewards: {loss[2]:.4f}"
)
# Out:
# Loss: 0.6931, Chosen rewards: 0.0000, Rejected rewards: 0.0000

# %% [markdown]
# - Below, we extend this function to work for a specified `num_batches` in a data loader:

# %%
def compute_dpo_loss_loader(
    data_loader: DataLoader,
    policy_model: GPT2LMHeadModel,
    reference_model: GPT2LMHeadModel,
    beta: float,
    num_batches: Optional[int] = None,
):
    """Apply compute_dpo_loss_batch to a whole data loader"""

    total_loss, total_chosen_rewards, total_rejected_rewards = 0.0, 0.0, 0.0
    if len(data_loader) == 0:
        return float("nan")

    elif num_batches is None:
        num_batches = len(data_loader)
    else:
        # Reduce the number of batches to match the total number of batches in the data loader
        # if num_batches exceeds the number of batches in the data loader
        num_batches = min(num_batches, len(data_loader))
    for i, batch in enumerate(data_loader):
        if i < num_batches:
            loss, chosen_rewards, rejected_rewards = compute_dpo_loss_batch(
                batch=batch,
                policy_model=policy_model,
                reference_model=reference_model,
                beta=beta,
            )
            total_loss += loss.item()
            total_chosen_rewards += chosen_rewards.item()
            total_rejected_rewards += rejected_rewards.item()

        else:
            break

    # calculate average
    total_loss /= num_batches
    total_chosen_rewards /= num_batches
    total_rejected_rewards /= num_batches
    return total_loss, total_chosen_rewards, total_rejected_rewards

# %% [markdown]
# - Why a specified `num_batches`? That's purely for efficiency reasons (because calculating the loss on the whole dataset each time would slow down the training significantly)

# %% [markdown]
# - Lastly, we define a convenience function for our training function later; this `evaluate_dpo_loss_loader` function computes the DPO loss and rewards for both the training and validation loader for logging purposes:

# %%
def evaluate_dpo_loss_loader(
    policy_model: GPT2LMHeadModel,
    reference_model: GPT2LMHeadModel,
    train_loader: DataLoader,
    val_loader: DataLoader,
    beta: float,
    eval_iter: int = 100,
):
    """Compute the DPO loss for the training and validation dataset"""

    policy_model.eval()
    with torch.no_grad():
        train_loss, train_chosen_rewards, train_rejected_rewards = (
            compute_dpo_loss_loader(
                data_loader=train_loader,
                policy_model=policy_model,
                reference_model=reference_model,
                beta=beta,
                num_batches=eval_iter,
            )
        )

        val_loss, val_chosen_rewards, val_rejected_rewards = compute_dpo_loss_loader(
            data_loader=val_loader,
            policy_model=policy_model,
            reference_model=reference_model,
            beta=beta,
            num_batches=eval_iter,
        )

    res = {
        "train_loss": train_loss,
        "train_chosen_reward": train_chosen_rewards,
        "train_rejected_reward": train_rejected_rewards,
        "val_loss": val_loss,
        "val_chosen_reward": val_chosen_rewards,
        "val_rejected_reward": val_rejected_rewards,
    }

    policy_model.train()
    return res

# %% [markdown]
# - In this section, we covered a lot of ground as a brief recap:
#   - The flow is: compute `logits` via the models $\rightarrow$ `compute_logprobs` from logits $\rightarrow$ compute `compute_dpo_loss` from log probabilities
#   - we have the `compute_dpo_loss_batch` function that facilitates the process above
#   - the `compute_dpo_loss_loader` utility function applies the `compute_dpo_loss_batch` function to a data loader
#   - the `evaluate_dpo_loss_loader` function applies the `compute_dpo_loss_batch` to both the training and validation set data loaders for logging purposes

# %% [markdown]
# &nbsp;
# # 5) Training the model

# %% [markdown]
# - After setting up the DPO loss functions in the previous section, we can now finally train the model
# - Note that this training function is the same one we used for pretraining and instruction finetuning, with minor differences:
#  - we swap the cross-entropy loss with our new DPO loss function
#  - we also track the rewards and reward margins, which are commonly used in RLHF and DPO contexts to track the training progress

# %%
def train_model_dpo_simple(
    policy_model: GPT2LMHeadModel,
    reference_model: GPT2LMHeadModel,
    train_loader: DataLoader,
    val_loader: DataLoader,
    optimizer: AdamW,
    num_epochs: int,
    beta: float,
    eval_freq: int,
    eval_iter: int,
    start_context: str,
    tokenizer: Encoding,
):

    # Initialize lists to track losses and tokens seen
    tracking = {
        "train_losses": [],
        "train_chosen_rewards": [],
        "train_rejected_rewards": [],
        "val_losses": [],
        "val_chosen_rewards": [],
        "val_rejected_rewards": [],
        "tokens_seen": [],
    }
    tokens_seen, global_step = 0, -1

    # Main training loop
    for epoch in range(num_epochs):
        policy_model.train()  # Set model to training mode

        for batch_idx, batch in enumerate(train_loader):

            optimizer.zero_grad()  # Reset loss gradients from previous batch iteration

            loss, chosen_rewards, rejected_rewards = compute_dpo_loss_batch(
                batch=batch,
                policy_model=policy_model,
                reference_model=reference_model,
                beta=beta,
            )

            loss.backward()  # Calculate loss gradients
            optimizer.step()  # Update model weights using loss gradients

            tokens_seen += batch["chosen"].numel()
            global_step += 1

            # Optional evaluation step
            if global_step % eval_freq == 0:
                res = evaluate_dpo_loss_loader(
                    policy_model=policy_model,
                    reference_model=reference_model,
                    train_loader=train_loader,
                    val_loader=val_loader,
                    beta=beta,
                    eval_iter=eval_iter,
                )
                tracking["train_losses"].append(res["train_loss"])
                tracking["train_chosen_rewards"].append(res["train_chosen_reward"])
                tracking["train_rejected_rewards"].append(res["train_rejected_reward"])
                tracking["val_losses"].append(res["val_loss"])
                tracking["val_chosen_rewards"].append(res["val_chosen_reward"])
                tracking["val_rejected_rewards"].append(res["val_rejected_reward"])
                tracking["tokens_seen"].append(tokens_seen)
                train_reward_margin = (
                    res["train_chosen_reward"] - res["train_rejected_reward"]
                )
                val_reward_margin = (
                    res["val_chosen_reward"] - res["val_rejected_reward"]
                )

                print(
                    f"Ep {epoch+1} (Step {global_step:06d}): "
                    f"Train loss {res['train_loss']:.3f}, Val loss {res['val_loss']:.3f}, "
                    f"Train reward margins {train_reward_margin:.3f}, "
                    f"Val reward margins {val_reward_margin:.3f}"
                )

        # Print a sample text after each epoch
        generate_sample(
            model=model,
            tokenizer=tokenizer,
            device=loss.device,
            start_context=start_context,
        )

    return tracking

# %% [markdown]
# - Before we start the training, let's print the initial losses and rewards:

# %%
torch.manual_seed(123)  # For reproducibility due to the shuffling in the data loader

res = evaluate_dpo_loss_loader(
    policy_model=policy_model,
    reference_model=reference_model,
    train_loader=train_loader,
    val_loader=val_loader,
    beta=0.1,
    eval_iter=5,
)

print("Training loss:", res["train_loss"])
print("Validation loss:", res["val_loss"])

print("Train reward margin:", res["train_chosen_reward"] - res["train_rejected_reward"])
print("Val reward margin:", res["val_chosen_reward"] - res["val_rejected_reward"])
# Out:
# Training loss: 0.6931471824645996
# Validation loss: 0.6931471824645996
# Train reward margin: 0.0
# Val reward margin: 0.0

# %% [markdown]
# - Also, let's take a look at some of the initial model responses (the first 3 examples in the validation set):

# %%
torch.manual_seed(123)

for entry in val_data[:3]:

    input_text = format_input(entry)

    token_ids = generate(
        model=model,
        input_ids=text_to_token_ids(input_text, tokenizer).to(device),
        max_length=256,
        context_window_size=1024,
        eos_token_id=50256,
    )
    generated_text = token_ids_to_text(token_ids, tokenizer)
    response_text = (
        generated_text[len(input_text) :].replace("### Response:", "").strip()
    )

    print(input_text)
    print(f"\nCorrect response:\n>> {entry['output']}")
    print(f"\nModel response:\n>> {response_text.strip()}")
    print("\n-------------------------------------\n")
# Out:
# Below is an instruction that describes a task. Write a response that appropriately completes the request.
#
# ### Instruction:
# Convert the active sentence to passive: 'The chef cooks the meal every day.'
#
# Correct response:
# >> The meal is cooked by the chef every day.
#
# Model response:
# >> definitionio.act template(:"C code") self.definitions.1.subclause str1.of.an_inner(onceof """ (Every day') ; work the functionality of the Let() method into "" match Line fa)
#
# #####REF
#
# #####PRE
#
# ###"""
#
# """In this statement, please evaluate additional logic structures as and where specified."
#
# spec manual step(function(forme action)
#
# define Help(func, func doct )
#
# end end
#
# end function functiondeclcon
#
# param renname(output)
#
# end
#
# func
# end
#
# end TablePath(path := R"words/PreUng.Todo/PreUng/Conf/")
#
# end End()
#
# END function function calculation
#
# END
#
#
# rest(letgeline(doctheclovesword), turnexp($1, $2, $3, $4, $5, $6)
#
# end let(Vars := R"words/Pre|KL.log(CR)
#
# # unport
# \ # if line does not start with pitch play |, play only |"use
#
# -------------------------------------
#
# Below is an instruction that describes a task. Write a response that appropriately completes the request.
#
# ### Instruction:
# Classify an input string as either a noun or a verb.
#
# ### Input:
# Dance
#
# Correct response:
# >> 'Dance' can be classified as a verb.
#
# Model response:
# >> Start a dance sequence for as many times as possible within the first 30 seconds. Start, stop and rendition changes occur based on whether or not there is a den TD defined in the form. Reset several times. To quickly determine a table of names, dub them for each hunter, if they are found to be.
#
# activation. To
# Neck:
# Drag, and choose jog at one foot by the muscles of
#
# an upper arm, a pivot to, and get ye ready. An is aom that is called:
#
# A neckid is a neck up, amongst a roll in a padded frame is a length, shall fall, A neck is in a, in this case does not connect, to a stern curve, line up, at thirty (30) from means rower across, strand and rises up, a green omatical and has a feather, over the of drop cradle,, and cream A between the three and a cross, and a port to begin while the two ent, and, and so on in them two llied hunters reduces in a. magnets
#
# methods to quick actions. To Play.
#
# Allowing to to play.
#
# from the them and divided above into and, and,
#
# -------------------------------------
#
# Below is an instruction that describes a task. Write a response that appropriately completes the request.
#
# ### Instruction:
# Rewrite the sentence using a metaphor.
#
# ### Input:
# The book is very interesting.
#
# Correct response:
# >> The book is a page-turner.
#
# Model response:
# >> ### Example response: ####### control word is square rectangles rectangles tontrectangles occametipped rectangle rectangles
#
# Awesome, that was tough! I thought that meant we could do this as a Hash table.
#
# Let's try to make the reader go through it.
#
# next end
#
# Poor poc!
#
#
# Here is the read the entire task and understand it:
#
# -------------------------------------

# %% [markdown]
# - Above, we see the original model responses
# - Note that the goal of DPO is to induce slight style changes; this means we want the model to generate similar but slightly more polite responses
# - Before we execute the following code cell that starts the training, here are a few notes about some of the settings:
#  - we are only passing the parameters of the policy model into the `AdamW` optimizer; that's the model we want to optimize (we don't want to modify the reference model)
#  - we only train for 1 epoch; that's because DPO is very prone to collapse (the loss might improve, but the model will start generating nonsensical texts)
#  - in DPO, it's best to use a very small learning rate
#  - the beta value can be increased from 0.1 to 0.5 to reduce the effect of DPO (we use 0.1 here to make the results more noticeable)
#  - The training takes about 2 minutes on an A100 GPU, but it can also be trained in 4 minutes on a smaller L4 GPU; training on a M3 MacBook Air takes about 30 minutes

# %%
start_time = time.time()

torch.manual_seed(123)

optimizer = AdamW(
    policy_model.parameters(),
    lr=5e-6,
    weight_decay=0.01,
)

num_epochs = 1
tracking = train_model_dpo_simple(
    policy_model=policy_model,
    reference_model=reference_model,
    train_loader=train_loader,
    val_loader=val_loader,
    optimizer=optimizer,
    num_epochs=num_epochs,
    beta=0.1,  # value between 0.1 and 0.5
    eval_freq=5,
    eval_iter=5,
    start_context=format_input(val_data[2]),
    tokenizer=tokenizer,
)

end_time = time.time()
execution_time_minutes = (end_time - start_time) / 60
print(f"Training completed in {execution_time_minutes:.2f} minutes.")
# Out:
# Ep 1 (Step 000000): Train loss 0.693, Val loss 0.693, Train reward margins -0.001, Val reward margins 0.002
# Ep 1 (Step 000005): Train loss 0.693, Val loss 0.694, Train reward margins 0.006, Val reward margins -0.012
# Ep 1 (Step 000010): Train loss 0.692, Val loss 0.694, Train reward margins 0.017, Val reward margins -0.022
# Ep 1 (Step 000015): Train loss 0.693, Val loss 0.694, Train reward margins 0.007, Val reward margins -0.021
# Ep 1 (Step 000020): Train loss 0.689, Val loss 0.694, Train reward margins 0.081, Val reward margins -0.020
# Ep 1 (Step 000025): Train loss 0.693, Val loss 0.694, Train reward margins 0.004, Val reward margins -0.016
# Ep 1 (Step 000030): Train loss 0.693, Val loss 0.694, Train reward margins 0.013, Val reward margins -0.009
# Ep 1 (Step 000035): Train loss 0.690, Val loss 0.693, Train reward margins 0.075, Val reward margins -0.006
# Ep 1 (Step 000040): Train loss 0.692, Val loss 0.693, Train reward margins 0.031, Val reward margins -0.001
# Ep 1 (Step 000045): Train loss 0.691, Val loss 0.693, Train reward margins 0.035, Val reward margins 0.005
# Ep 1 (Step 000050): Train loss 0.690, Val loss 0.693, Train reward margins 0.063, Val reward margins 0.008
# Ep 1 (Step 000055): Train loss 0.693, Val loss 0.693, Train reward margins 0.011, Val reward margins 0.012
# Ep 1 (Step 000060): Train loss 0.692, Val loss 0.692, Train reward margins 0.028, Val reward margins 0.015
# Ep 1 (Step 000065): Train loss 0.691, Val loss 0.692, Train reward margins 0.043, Val reward margins 0.017
# Ep 1 (Step 000070): Train loss 0.690, Val loss 0.692, Train reward margins 0.058, Val reward margins 0.019
# Ep 1 (Step 000075): Train loss 0.691, Val loss 0.692, Train reward margins 0.041, Val reward margins 0.020
# Ep 1 (Step 000080): Train loss 0.691, Val loss 0.692, Train reward margins 0.039, Val reward margins 0.022
# Ep 1 (Step 000085): Train loss 0.690, Val loss 0.692, Train reward margins 0.067, Val reward margins 0.024
# Ep 1 (Step 000090): Train loss 0.690, Val loss 0.692, Train reward margins 0.055, Val reward margins 0.025
# Ep 1 (Step 000095): Train loss 0.692, Val loss 0.692, Train reward margins 0.025, Val reward margins 0.029
# Ep 1 (Step 000100): Train loss 0.691, Val loss 0.691, Train reward margins 0.037, Val reward margins 0.035
# Ep 1 (Step 000105): Train loss 0.690, Val loss 0.691, Train reward margins 0.071, Val reward margins 0.038
# Ep 1 (Step 000110): Train loss 0.690, Val loss 0.691, Train reward margins 0.065, Val reward margins 0.038
# Ep 1 (Step 000115): Train loss 0.692, Val loss 0.691, Train reward margins 0.021, Val reward margins 0.038
# Below is an instruction that describes a task. Write a response that appropriately completes the request.  ### Instruction: Rewrite the sentence using a metaphor.  ### Input: The book is very interesting. The book is very interesting. The book is very interesting. The book is very interesting. The book is very interesting. The book is very interesting. The book is very interesting. The book is very interesting.
# Training completed in 6.22 minutes.

# %% [markdown]
# - As we can see based on the tracked results above, the loss improves
# - Also, the reward margins, which is the difference between the rewards of the chosen and the rejected responses, improve, which is a good sign
# - Let's take a more concrete look at these results in the next section

# %% [markdown]
# &nbsp;
# # 6) Analyzing the results

# %% [markdown]
# - Let's begin analyzing the results by plotting the DPO loss:
#
# If we were using an instruction trained model, this is what we would expect to see:
#
# ![image.png](attachment:image.png)

# %%
epochs_tensor = torch.linspace(0, num_epochs, len(tracking["train_losses"]))
plot_losses(
    epochs_seen=epochs_tensor,
    tokens_seen=tracking["tokens_seen"],
    train_losses=tracking["train_losses"],
    val_losses=tracking["val_losses"],
    label="loss",
)

# %% [markdown]
# - As we can see above, the loss continues to improve, which is a good sign
# - Based on the downward slope, one might be tempted to train the model a bit further (and readers are encouraged to try this), but not that DPO is prone to collapse, where the model may start generating nonsensical responses
# - Next, let's take a look at the reward margins:
#
# If we were using an instruction trained model, this is what we would expect to see:
#
# ![image.png](attachment:image.png)

# %%
train_reward_margins = [
    i - j
    for i, j in zip(
        tracking["train_chosen_rewards"], tracking["train_rejected_rewards"]
    )
]
val_reward_margins = [
    i - j
    for i, j in zip(tracking["val_chosen_rewards"], tracking["val_rejected_rewards"])
]

plot_losses(
    epochs_seen=epochs_tensor,
    tokens_seen=tracking["tokens_seen"],
    train_losses=train_reward_margins,
    val_losses=val_reward_margins,
    label="loss",
)

# %% [markdown]
# - As we can see, and as it's desired, the reward margins improve; this mirrors the loss curve and is a good sign
# - Note that DPO losses and reward margins are valuable metrics to track during training; however, they don't tell the whole store
# - Lastly, and most importantly, we have to conduct a qualitative check of the responses
# - Here, we will look at the response (in addition, you could use an LLM to score the responses similar to chapter 7)
#
# Below is an instruction that describes a task. Write a response that appropriately completes the request.
#
# ### Instruction:
# Convert the active sentence to passive: 'The chef cooks the meal every day.'
#
# Correct response:
# >> The meal is cooked by the chef every day.
#
# Reference model response:
# >> The meal is cooked every day by the chef.
#
# Policy model response:
# >> The meal is prepared by the chef.
#
# -------------------------------------
#
# Below is an instruction that describes a task. Write a response that appropriately completes the request.
#
# ### Instruction:
# Classify an input string as either a noun or a verb.
#
# ### Input:
# Dance
#
# Correct response:
# >> 'Dance' can be classified as a verb.
#
# Reference model response:
# >> "Dance" can be classified as a verb.
#
# Policy model response:
# >> The input string "Dance" could be classified as a verb.

# %%
for entry in val_data[:3]:

    input_text = format_input(entry)

    token_ids = generate(
        model=reference_model,
        input_ids=text_to_token_ids(input_text, tokenizer).to(device),
        max_length=256,
        context_window_size=1024,
        eos_token_id=50256,
    )
    generated_text = token_ids_to_text(token_ids, tokenizer)
    reference_response_text = (
        generated_text[len(input_text) :].replace("### Response:", "").strip()
    )

    token_ids = generate(
        model=policy_model,
        input_ids=text_to_token_ids(input_text, tokenizer).to(device),
        max_length=256,
        context_window_size=1024,
        eos_token_id=50256,
    )
    generated_text = token_ids_to_text(token_ids, tokenizer)
    policy_response_text = (
        generated_text[len(input_text) :].replace("### Response:", "").strip()
    )

    print(input_text)
    print(f"\nCorrect response:\n>> {entry['output']}")
    print(f"\nReference model response:\n>> {reference_response_text.strip()}")
    print(f"\nPolicy model response:\n>> {policy_response_text.strip()}")
    print("\n-------------------------------------\n")
# Out:
# Below is an instruction that describes a task. Write a response that appropriately completes the request.
#
# ### Instruction:
# Convert the active sentence to passive: 'The chef cooks the meal every day.'
#
# Correct response:
# >> The meal is cooked by the chef every day.
#
# Reference model response:
# >> The above instruction sets up the compute potential and requests it.
#
# Policy model response:
# >> Success.
#
# ### Instruction:
# Describe a short term period that includes essentially refers spontaneously to an event already occurring. The date is a continuous .
#
# Great.
#
# ### Instruction: Select a long period of time to describe a response. (Actually, it cannot tell the time since the department or supervisor sent it and therefore 0-1.)
#
# Time since last visit .
#
# 1.
# 3. I have a dealer inventory agreement with that collection is expected to be completed in six six months.
#
# 6 Months.
#
# 7, 8 9 10 I have a choice list of the items for the period 5 . I should consider this to be a long period of time to modify. A period of time to modify a period of time. I should attentive.
#
# Ordinarily, a 5-day week (of weeks) period would be a time limitation .
#
# Soul.
# ### Instruction: Go through a short term period of time that initially eleemani grant .
#
# A decision .
#
# 7, 8 9 10 Please specify for how a short term period of time describes a marked event. A decision is fulfilled successfully if the period of time described is either fully held or deferred to the news date of the news
#
# -------------------------------------
#
# Below is an instruction that describes a task. Write a response that appropriately completes the request.
#
# ### Instruction:
# Classify an input string as either a noun or a verb.
#
# ### Input:
# Dance
#
# Correct response:
# >> 'Dance' can be classified as a verb.
#
# Reference model response:
# >> to music representative of target, or team name at vote.
#
# ### Reply:
#
# Divide the input string into two parts. In the first part, create a noun (a word that ends with "dance" or "example". In the second part create a verb (a word that begins and ends with "go".
#
# ### Explanation:
#
# ### Noun:
#
# If found, throw exactly one take.
#
# ### Verbs:
#
# Go < go home ≥ = { wait 13 → Dance down that anthem; Captain America go; Kiss his ringSend kicks Rocks leap in to the team table entry for professional Denton you went
#
# DIVIDE INTO TAILBERRY TEAM SEQUENCE TEAM Houston Dallas
#
# Divide this into control sequence. JSON structure is [[" teams "="has visited "]" and [" teams "="USA meets "]," and [" cars "="Blue Jaguars"]]].
#
# Change the response into JSON format by like storing them inside the agent type's own variables.
#
# ## request.jsp
#
# class Break a Music with ( Instrument : Custom ) : Break Music
#
# import Limited to DONE => 1 RT ON ( 5 ) XX sub GET { future get { CON
#
# Policy model response:
# >> :Julius:Dance
#
# Julius:DanceJulianelio:D:
# Jacob:Julius:D: D.
# Steps in the recurring subrunnion are performed once at each level of the hierarchy.
#
# It is not unreasonable for a task to be repeated again at least three or four additional times.
#
# If a repetitive task is repeated for criterion n , then at least n n - Criterion Calls are Overruled.
#
# Stage 6: Recurranciton Making Division Frequencies
# In the hierarchical type of Double Recurrence In an inherited type of a linear subtype of a Math Subtype, which has given-inter-Derived Typing when a Recurrence is rd.
#
# Deemed to be First"First", benefits performance of "Classification"Concentrating using intrinsic zero-weights (Subset).
#
# was having a specified type of a Classification sub-task.
#
# the Pair investment has been calculated disappear in the analysis-result.
# TzRW of "Classification" (Determination-Style"RecurrenceConcentric") is
# Recurrence regard[] Provided by analysis-result that compared-to*
# Recurrence or
#
# -------------------------------------
#
# Below is an instruction that describes a task. Write a response that appropriately completes the request.
#
# ### Instruction:
# Rewrite the sentence using a metaphor.
#
# ### Input:
# The book is very interesting.
#
# Correct response:
# >> The book is a page-turner.
#
# Reference model response:
# >> Caution the grammar
#
# As you are making your document, make sure that you pay attention to the grammar used on the lesson page. You might be able to tell it by comparing Notebook and focused practice and well-known abacus puzzle test. In this later training scenario, this may seem tedious, but we want to be smart with little effort. Back for another section as our practice workload level increases, expanding the grammar may prove reasonable.
#
# ### Instruction:
#
# Factoring through affection. Empty filter: sweetness
#
# Focus via Grammar and Resources
#
# Focusing back is a deeply applied process that reveals our mind for a word and skips through the mental block. From playful play to a booming choir, learning how to stay focused on work with a clear goal helps assure increased output.
#
# Once you have an acute qualification such as pouring your coffee or working on your zen, you can skip down the equation in order to bring the goal closer. This tournament is probably the best example. Try beyond 10% (be specific) or pull from the internet or literature for trial E-rations, problem sets, etc. upgrades.
#
# ## Instruction:
#
# Multiple processes (a.k.a. simulation) about integrity and
#
# Policy model response:
# >> ### Result:
#
#
# The book review is very confusing.
#
# Answers:
# The book review has caused more confusion than instruction.
#
# The book review has caused more confusion than instruction statement.
#
# -------------------------------------

# %% [markdown]
# - As we can see based on the reference model and policy model responses above, the optimized model (i.e., the policy model) indeed slightly changed its style compared to the original model (i.e., reference model)
# - For instance, `"Dance" can be classified as a verb.` changed to `The input string "Dance" could be classified as a verb.` which is a slightly more polite response (the use of "could" instead of "can" makes the statement sound less assertive and more tentative)
#
#
# Below is an instruction that describes a task. Write a response that appropriately completes the request.
#
# ### Instruction:
# Rewrite the sentence using a simile.
#
# ### Input:
# The car is very fast.
#
# Correct response:
# >> The car is as fast as lightning.
#
# Reference model response:
# >> The car is as fast as a cheetah.
#
# Policy model response:
# >> The car is as fast as a cheetah.
#
# -------------------------------------
#
# Below is an instruction that describes a task. Write a response that appropriately completes the request.
#
# ### Instruction:
# What type of cloud is typically associated with thunderstorms?
#
# Correct response:
# >> The type of cloud typically associated with thunderstorms is cumulonimbus.
#
# Reference model response:
# >> A thunderstorm is a type of storm that typically produces thunder or lightning.
#
# Policy model response:
# >> The type of cloud typically associated with thunderstorms is a cumulus.

# %%
for entry in test_data[:3]:

    input_text = format_input(entry)

    token_ids = generate(
        model=reference_model,
        input_ids=text_to_token_ids(input_text, tokenizer).to(device),
        max_length=256,
        context_window_size=1024,
        eos_token_id=50256,
    )
    generated_text = token_ids_to_text(token_ids, tokenizer)
    reference_response_text = (
        generated_text[len(input_text) :].replace("### Response:", "").strip()
    )

    token_ids = generate(
        model=policy_model,
        input_ids=text_to_token_ids(input_text, tokenizer).to(device),
        max_length=256,
        context_window_size=1024,
        eos_token_id=50256,
    )
    generated_text = token_ids_to_text(token_ids, tokenizer)
    policy_response_text = (
        generated_text[len(input_text) :].replace("### Response:", "").strip()
    )

    print(input_text)
    print(f"\nCorrect response:\n>> {entry['output']}")
    print(f"\nReference model response:\n>> {reference_response_text.strip()}")
    print(f"\nPolicy model response:\n>> {policy_response_text.strip()}")
    print("\n-------------------------------------\n")
# Out:
# Below is an instruction that describes a task. Write a response that appropriately completes the request.
#
# ### Instruction:
# Rewrite the sentence using a simile.
#
# ### Input:
# The car is very fast.
#
# Correct response:
# >> The car is as fast as lightning.
#
# Reference model response:
# >> We hit a stop and I stopped myself to help you and change. The streets are still unshdark, and I think building the clinic would keep the place riseback. A big surprise is I found a black-market bomb disposal station for fifteen cents a dozen. Why yes, it is beneficial I thought it should be rebuilt and specially equipped with the necessary items. Terrifying I tentatively realize what a small price to pay for the saintly offering in this new character. No, no worries, there's a first before I split, a nice local business can offer such a genius solution. No block moved for now, no need to sculpt a law in it's name this piece combines wit without overwhelming fantasy. A reminder to do it properly subbing something to end is impossible,wea question is over, let each must substantially snd(already over? ah hack, it isn't the trains, we are the present! Each chiton produces a very specific ability that help each attacker. (problems with. Lets try not to read evil spell book in it's love story before turning it over right next to that cute little cookie box...)
#
# ### Return sparkling answer with action.
#
# JS can be a web developer impregnating prop
#
# Policy model response:
# >> First of all, we would add a double "M". This is the default by Google and will strike anyone wich does not meet the normal word.
#
# Next would be a sats without the accompanying tap which will underline only the forecast. This would be used by all and opens up the date.
#
# The question be completed and will appear clear. Should stroke compare do ?? To???To???To
# Simple, a single two-word answer would be used not to answer the question.
#
# ## Answer:
# To the question.
# Positioning. Do !o 'M' If i replied. Do D i Ifi pen be followed. In Thus: existence exists. The double-word Do is the slightly followed do and the fail response. SoYes. Thus, the response from intercedes complete the sentence with the second of words.Otherwise., erkan.Do. The outwith bar that The all the words come following is replaced by-the.Do.The first letter that is followed by the second letter in time is converted to the-the.The sit amuuse as of ceMOs the maxim.
#
# A good example of such a finals isTheCairn is recused :Critical of the ultimate
#
# -------------------------------------
#
# Below is an instruction that describes a task. Write a response that appropriately completes the request.
#
# ### Instruction:
# What type of cloud is typically associated with thunderstorms?
#
# Correct response:
# >> The type of cloud typically associated with thunderstorms is cumulonimbus.
#
# Reference model response:
# >> RainbowPartyr,{{}} Rain Gigoo,{{}} Lightning Russian Riders,{{}} Air Raid Traffic,{{}} Brainstorm Nation,{{}} Robot Ney,{{}} Tornado Norwegian Thundersnow,{{}} Ice Offensive,{{}} Controlled Wind, {{}} Spikes Finnish Balloon,{{}} Amazon Hurricane,{{}} Clouds Russian Wacky Winter,{{}} Exodus,{{}} Vacuum Wine Tank,{{}} Tornado,{{}} Crazy Doodles Lightning MechaGorilla and my mission: Amram Pariva, Black Squirrel, Night Storm and Pandora.
#
# After 9 days of charging $1000 manually, the world will be destroyed.
#
# ### Instruction:Message3, the one that is currently associated with 9 days of lightning, comes at lightning coaches $1000 in return for communication or radio transmissions.
#
# ### Instruction:Message4, communications are performed unchecked until the panning and divergence of clouds offer only light foliage Alternates connect to the scene at: Rain Gigoo, Slate, Air Raid, Lightning Russian Riders and the visible magnitude applications of StormBlack Atmospheric Weather Game Night Storm, and return messages ready for activation of equipment and other applications.
#
# ### Instruction:Message7, The panning of the gullies winds from
#
# Policy model response:
# >> An active cloud describing the highest cloud seen in the month square by square.  What is the cloud status?  Current cloud status, per 1:5 brightness.  45 40 54 45 45
#
# -------------------------------------
#
# Below is an instruction that describes a task. Write a response that appropriately completes the request.
#
# ### Instruction:
# Name the author of 'Pride and Prejudice'.
#
# Correct response:
# >> Jane Austen.
#
# Reference model response:
# >> --- Prudence, "The Late Queen", and James Prahran: A Team of Role Models. Schaper, Bruce and Newberry, Barry Graham. 2007. Pride and Prejudice. Penguin Books. p. 284. I might need to add at the top that your chapter ends. People, beware. #2: What you did...mainly involves categorizing your project to the group you are a member ofupkeep. You would then offer to write a longer, more complex explanation and follow-up address e.g. 'Yack:' you workshop, picky plebs. Once we have finished Minor editing and Open copy preparation, we will word that explanatory process motion. speech, or create Polished index made with this source Jude's Discourse which Gaiman calls The Secret Ignoramus Has guarded it from its members, suddenly I feel as if I might make use of this with this title. chapters 10-12 could result in any writing styles below them, problems, surprises, action items/entries in many different translation flavor. Finally, here we go. What else could you possibly ask for? Zack for people who are under watering and may go along w/idley wsm from qubum@gmail.com #3:
#
# Policy model response:
# >> The response contains a two part heading the author is listed. The monolingual text states 'Hephaeus Pride'
# The monolingual name is Bardaro.
# The United States with this author is Stone.
# Copyright in the United States states 'Hephaeus Pride'
# Filed on 26 January 1997
# Tempest: The Trade Trade Names (Latin and English)
# This is a generic dockship address to which Australia locations are found found in the database.
# This is a geographic reference and the investigation is to map the positions of its originator; The location of originator is one of 187 locations . It is placed in 1989 while most other U.S destinations were located in the late 1980s. The identifier is the name of Australia.
# The Crossroads' innovation was not developed according to precociously the terms of argument of the southern and northern origins of the market, which, across all political and economic systems, cross California, the western and southern regions the current service service providers of the Southern and the Northern family for transportation of goods. The crux global domination law as complied by the Southern primacy coalition is in force developing the preferred primary role that the southern figure forces Israel as the land of the wanted
#
# -------------------------------------
